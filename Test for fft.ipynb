# %% [markdown]
# This is a test for scipy.fft.fft and scipy.fft.ifft

# %% [markdown]
# ## The FFT peak for the velocity in x direction
#
# - T = 0.03 micro seconds(omit for later)
#
# ![image.png](attachment:image-2.png)

# %% [markdown]
# - T = 0.06
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.12
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.18
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.24
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.25
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.26
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.27
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.28
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.29
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.30
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - T = 0.50
#
# ![image.png](attachment:image.png)
